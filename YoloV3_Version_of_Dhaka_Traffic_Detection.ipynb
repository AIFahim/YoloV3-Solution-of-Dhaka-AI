# %% [markdown]
# ## Setup
# We have configure the YOLOV3 Ultralytics repository to train the traffic dataset. In this example we are going to use 30% of the dataset for training and testing.

# %%
# !git clone https://github.com/rifat963/yolov3-wrapper-for-custom-data.git
# Out:
# Cloning into 'yolov3-wrapper-for-custom-data'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 107 (delta 38), reused 91 (delta 24), pack-reused 0
# Receiving objects: 100% (107/107), 871.67 KiB | 2.56 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
from IPython.display import clear_output

# %cd /content/yolov3-wrapper-for-custom-data/data
# !gdown --id 1nl0jc9hrZ8wqZ4DHv5MxDecFDBIYSzPa
# !unzip traffic-dataset.zip; rm traffic-dataset.zip;
clear_output()

# %%
# %cd /content/yolov3-wrapper-for-custom-data/weights/
# !gdown --id 1UcR-zVoMs7DH5dj3N1bswkiQTA4dmKF4
# Out:
# /content/yolov3-wrapper-for-custom-data/weights
# Downloading...
# From: https://drive.google.com/uc?id=1UcR-zVoMs7DH5dj3N1bswkiQTA4dmKF4
# To: /content/yolov3-wrapper-for-custom-data/weights/yolov3-spp-ultralytics.pt
# 252MB [00:02, 108MB/s]

# %% [markdown]
# # Training

# %%
# %cd /content/yolov3-wrapper-for-custom-data

# !python train.py --cfg cfg/yolov3-spp-23cls.cfg \
                 --data traffic.data \
                 --epochs 100 \
                 --batch-size 8 \
                 --weights weights/yolov3-spp-ultralytics.pt \
                 --name yolov3-traffic
# Out:
# /content/yolov3-wrapper-for-custom-data
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Namespace(adam=False, batch_size=8, bucket='', cache_images=False, cfg='cfg/yolov3-spp-23cls.cfg', data='traffic.data', device='', epochs=100, evolve=False, freeze_layers=False, img_size=[320, 640], multi_scale=False, name='yolov3-traffic', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# 2020-09-15 09:41:34.733860: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Model Summary: 225 layers, 6.26649e+07 parameters, 6.26649e+07 gradients
# Optimizer groups: 76 .bias, 76 Conv2d.weight, 73 other
# Reading image shapes: 100% 696/696 [00:00<00:00, 9001.35it/s]
# Caching labels train.txt (696 found, 0 missing, 0 empty, 2 duplicate, for 696 images): 100% 696/696 [00:00<00:00, 5992.37it/s]
# Reading image shapes: 100% 199/199 [00:00<00:00, 12044.08it/s]
# Caching labels valid.txt (199 found, 0 missing, 0 empty, 0 duplicate, for 199 images): 100% 199/199 [00:00<00:00, 6583.63it/s]
# Image sizes 320 - 640 train, 640 test
# Using 2 dataloader workers
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#   0% 0/87 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/torch/cuda/memory.py:346: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)
#       0/99     11.1G       5.7      5.23      6.78      17.7        37       544: 100% 87/87 [00:58<00:00,  1.49it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1:   0% 0/25 [00:00<?, ?it/s]/content/yolov3-wrapper-for-custom-data/test.py:148: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#
/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.66it/s]
#                  all       199  1.39e+03     0.404     0.549     0.519     0.458
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      86/99     11.1G      1.27         1     0.387      2.66        73       448: 100% 87/87 [00:52<00:00,  1.64it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.78it/s]
#                  all       199  1.39e+03     0.459     0.565     0.531     0.491
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      87/99     11.1G      1.27     0.909     0.418      2.59        48       576: 100% 87/87 [00:53<00:00,  1.62it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.72it/s]
#                  all       199  1.39e+03     0.403     0.551     0.525     0.459
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      88/99     11.1G      1.28     0.974     0.429      2.68        56       352: 100% 87/87 [00:52<00:00,  1.66it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.77it/s]
#                  all       199  1.39e+03     0.402     0.559     0.528      0.46
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      89/99     11.1G      1.26     0.997      0.43      2.69        78       512: 100% 87/87 [00:52<00:00,  1.67it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.83it/s]
#                  all       199  1.39e+03     0.389     0.543     0.509     0.448
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      90/99     11.1G      1.24     0.903     0.412      2.55        43       480: 100% 87/87 [00:52<00:00,  1.66it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.70it/s]
#                  all       199  1.39e+03     0.398     0.553     0.518     0.456
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      91/99     11.1G      1.24     0.785     0.412      2.44        78       608: 100% 87/87 [00:53<00:00,  1.62it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.74it/s]
#                  all       199  1.39e+03     0.403     0.549      0.52     0.459
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      92/99     11.1G      1.26     0.919      0.36      2.54        42       384: 100% 87/87 [00:53<00:00,  1.64it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.81it/s]
#                  all       199  1.39e+03     0.406     0.541     0.512     0.457
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      93/99     11.1G      1.27     0.946     0.468      2.69        51       352: 100% 87/87 [00:52<00:00,  1.64it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.69it/s]
#                  all       199  1.39e+03     0.405     0.542      0.52     0.457
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      94/99     11.1G      1.25     0.822     0.419      2.49        40       448: 100% 87/87 [00:54<00:00,  1.61it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.65it/s]
#                  all       199  1.39e+03     0.408     0.557     0.528     0.464
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      95/99     11.1G      1.23     0.841     0.368      2.44        60       640: 100% 87/87 [00:53<00:00,  1.62it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.70it/s]
#                  all       199  1.39e+03     0.406     0.545     0.523      0.46
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      96/99     11.1G      1.24     0.869     0.416      2.53        64       608: 100% 87/87 [00:54<00:00,  1.60it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.70it/s]
#                  all       199  1.39e+03     0.404     0.548     0.519      0.46
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      97/99     11.1G      1.27     0.963     0.358      2.59        51       544: 100% 87/87 [00:52<00:00,  1.67it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.75it/s]
#                  all       199  1.39e+03     0.404     0.542     0.513     0.457
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      98/99     11.1G      1.23     0.828     0.401      2.46        78       640: 100% 87/87 [00:52<00:00,  1.64it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.81it/s]
#                  all       199  1.39e+03     0.391     0.544     0.516      0.45
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      99/99     11.1G      1.28     0.882     0.393      2.55        88       320: 100% 87/87 [00:51<00:00,  1.69it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 25/25 [00:06<00:00,  3.85it/s]
#                  all       199  1.39e+03     0.457     0.573     0.531     0.494
# Optimizer stripped from weights/last_yolov3-traffic.pt
# Optimizer stripped from weights/best_yolov3-traffic.pt
# 100 epochs completed in 1.742 hours.

# %% [markdown]
# # Inference

# %% [markdown]
# You can simply skip the training and download pre-trained weights for testing and inference.

# %%
# %cd /content/yolov3-wrapper-for-custom-data/weights

# !gdown --id 1-15l4qbualU09vgp-puXKAb2rfGB4bp_
# %cd ..
# Out:
# /content/yolov3-wrapper-for-custom-data/weights
# Downloading...
# From: https://drive.google.com/uc?id=1-15l4qbualU09vgp-puXKAb2rfGB4bp_
# To: /content/yolov3-wrapper-for-custom-data/weights/yolov4-obj_best.weights
# 256MB [00:01, 254MB/s]
# /content/yolov3-wrapper-for-custom-data

# %%
# %cd /content/yolov3-wrapper-for-custom-data/cfg

# !gdown --id 1DKwvcPZZF6ZauwJZz6lZzj4Ju9xWzoii
# %cd ..
# Out:
# /content/yolov3-wrapper-for-custom-data/cfg
# Downloading...
# From: https://drive.google.com/uc?id=1DKwvcPZZF6ZauwJZz6lZzj4Ju9xWzoii
# To: /content/yolov3-wrapper-for-custom-data/cfg/yolov4-obj.cfg
# 100% 12.3k/12.3k [00:00<00:00, 11.0MB/s]
# /content/yolov3-wrapper-for-custom-data

# %%
# !python detect.py --save-txt --names traffic.names --img-size 1024 --cfg cfg/yolov4-obj.cfg --weights weights/yolov4-obj_best.weights --source data/test
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov4-obj.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=1024, iou_thres=0.6, names='traffic.names', output='output', save_txt=True, source='data/test', view_img=False, weights='weights/yolov4-obj_best.weights')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Traceback (most recent call last):
#   File "detect.py", line 193, in <module>
#     detect()
#   File "detect.py", line 20, in detect
#     model = Darknet(opt.cfg, imgsz)
#   File "/content/yolov3-wrapper-for-custom-data/models.py", line 231, in __init__
#     self.module_defs = parse_model_cfg(cfg)
#   File "/content/yolov3-wrapper-for-custom-data/utils/parse_config.py", line 50, in parse_model_cfg
#     assert not any(u), "Unsupported fields %s in %s. See https://github.com/ultralytics/yolov3/issues/631" % (u, path)
# AssertionError: Unsupported fields ['stopbackward', 'max_delta'] in cfg/yolov4-obj.cfg. See https://github.com/ultralytics/yolov3/issues/631

# %% [markdown]
# ## All the results are in folder: /content/yolov3-wrapper-for-custom-data/output

# %% [markdown]
# # Test Submissions

# %%
# !python test.py -h
# Out:
# usage: test.py [-h] [--cfg CFG] [--data DATA] [--weights WEIGHTS]
#                [--batch-size BATCH_SIZE] [--img-size IMG_SIZE]
#                [--conf-thres CONF_THRES] [--iou-thres IOU_THRES] [--save-json]
#                [--task TASK] [--device DEVICE] [--single-cls] [--augment]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --cfg CFG             *.cfg path
#   --data DATA           *.data path
#   --weights WEIGHTS     weights path
#   --batch-size BATCH_SIZE
#                         size of each image batch
#   --img-size IMG_SIZE   inference size (pixels)
#   --conf-thres CONF_THRES
#                         object confidence threshold
#   --iou-thres IOU_THRES
#                         IOU threshold for NMS
#   --save-json           save a cocoapi-compatible JSON results file
#   --task TASK           'test', 'study', 'benchmark'
#   --device DEVICE       device id (i.e. 0 or 0,1) or cpu
#   --single-cls          train as single-class dataset
#   --augment             augmented inference

# %%
# !python test.py --data traffic.data --cfg cfg/yolov3-spp-23cls.cfg --weights weights/best_yolov3-traffic.pt --img 1024 --augment
# Out:
# Namespace(augment=True, batch_size=16, cfg='cfg/yolov3-spp-23cls.cfg', conf_thres=0.001, data='traffic.data', device='', img_size=1024, iou_thres=0.6, save_json=False, single_cls=False, task='test', weights='weights/best_yolov3-traffic.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.26649e+07 parameters, 6.26649e+07 gradients
# Fusing layers...
# Model Summary: 152 layers, 6.26381e+07 parameters, 6.26381e+07 gradients
# Reading image shapes: 100% 199/199 [00:00<00:00, 6999.01it/s]
# Caching labels valid.txt (199 found, 0 missing, 0 empty, 0 duplicate, for 199 images): 100% 199/199 [00:00<00:00, 8107.26it/s]
#                Class    Images   Targets         P         R   mAP@0.5        F1:   0% 0/13 [00:00<?, ?it/s]/content/yolov3-wrapper-for-custom-data/utils/utils.py:512: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   i, j = (x[:, 5:] > conf_thres).nonzero().t()
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 13/13 [00:24<00:00,  1.89s/it]
#                  all       199  1.39e+03     0.309     0.578     0.478     0.393
#        auto rickshaw       199        33     0.492     0.879     0.787      0.63
#              bicycle       199       204     0.504     0.873     0.812     0.639
#                  bus       199       393      0.56     0.898     0.859      0.69
#           garbagevan       199         2         0         0    0.0121         0
#         human hauler       199        70     0.247     0.643     0.465     0.357
#              minibus       199       114     0.514     0.807     0.776     0.628
#              minivan       199        98     0.265     0.582     0.372     0.365
#            motorbike       199         2         0         0   0.00597         0
#              Pickup        199       179     0.471      0.76     0.694     0.581
#         army vehicle       199         4         0         0  0.000263         0
#            policecar       199        28     0.102     0.643     0.167     0.176
#             rickshaw       199         5     0.572       0.8       0.8     0.667
#              scooter       199       139     0.522     0.856     0.828     0.649
#                  suv       199        85     0.552     0.847     0.742     0.669
#                 taxi       199        30     0.148     0.667      0.33     0.242
# three wheelers (CNG)       199         1         0         0   0.00201         0
# Speed: 99.9/2.2/102.1 ms inference/NMS/total per 1024x1024 image at batch-size 16

# %% [markdown]
# # Sample example to create submission file

# %%
from models import *  
from utils.datasets import *
from utils.utils import *

def detect(save_img=False):
    imgsz = opt.img_size 
    out, source, weights, half, view_img, save_txt = opt.output, opt.source, opt.weights, opt.half, opt.view_img, opt.save_txt

    # Initialize
    device = torch_utils.select_device(opt.device)
    if os.path.exists(out):
        shutil.rmtree(out)  # delete output folder
    os.makedirs(out)  # make new output folder

    # Initialize model
    model = Darknet(opt.cfg, imgsz)

    # Load weights
    attempt_download(weights)
    if weights.endswith('.pt'):  # pytorch format
        model.load_state_dict(torch.load(weights, map_location=device)['model'])
    else:  # darknet format
        load_darknet_weights(model, weights)

    
    # Eval mode
    model.to(device).eval()

    # Half precision
    half = half and device.type != 'cpu'  # half precision only supported on CUDA
    if half:
        model.half()

    # Set Dataloader
    vid_path, vid_writer = None, None
    save_img = True
    dataset = LoadImages(source, img_size=imgsz)

    # Get names and colors
    names = load_classes(opt.names)
    colors = [[random.randint(0, 255) for _ in range(3)] for _ in range(len(names))]

    # Run inference
    t0 = time.time()
    img = torch.zeros((1, 3, imgsz, imgsz), device=device)  # init img
    _ = model(img.half() if half else img.float()) if device.type != 'cpu' else None  # run once

    results=[]
    for path, img, im0s, vid_cap in dataset:
        img = torch.from_numpy(img).to(device)
        img = img.half() if half else img.float()  # uint8 to fp16/32
        img /= 255.0  # 0 - 255 to 0.0 - 1.0
        if img.ndimension() == 3:
            img = img.unsqueeze(0)

        # Inference
        t1 = torch_utils.time_synchronized()
        pred = model(img, augment=opt.augment)[0]
        t2 = torch_utils.time_synchronized()

        # to float
        if half:
            pred = pred.float()

        # Apply NMS
        pred = non_max_suppression(pred, opt.conf_thres, opt.iou_thres,
                                   multi_label=False, classes=opt.classes, agnostic=opt.agnostic_nms)

        
        # Process detections
        for i, det in enumerate(pred):  # detections for image i
            
            p, s, im0 = path, '', im0s          

            save_path = str(Path(out) / Path(p).name)
            #print(p)
            s += '%gx%g ' % img.shape[2:]  # print string
            #print(s)
            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  #  normalization gain whwh
            if det is not None and len(det):
                # Rescale boxes from imgsz to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += '%g %ss, ' % (n, names[int(c)])  # add to string

                xmin = []
                ymin = []
                xmax = []
                ymax = []
                scores = []
                labels_value=[]
                image_ids=[]
                # Write results
                for *xyxy, conf, cls in det:
                    if save_txt:  # Write to file
                        
                        conf_score = '%.2f' % (conf)
                        label_with_cls = '%s' % (names[int(cls)])
                        
                        labels_value.append(label_with_cls)
                        
                        xmin.append(int(xyxy[0]))
                        ymin.append(int(xyxy[1]))
                        xmax.append(int(xyxy[2]))
                        ymax.append(int(xyxy[3]))
                        
                        scores.append(conf_score)
                        image_ids.append(save_path)

                        xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
                        with open(save_path[:save_path.rfind('.')] + '.txt', 'a') as file:
                            file.write(('%g ' * 5 + '\n') % (cls, *xywh))  # label format

                    if save_img or view_img:  # Add bbox to image
                        label = '%s %.2f' % (names[int(cls)], conf)
                        plot_one_box(xyxy, im0, label=label, color=colors[int(cls)])

            # Print time (inference + NMS)
            print('%sDone. (%.3fs)' % (s, t2 - t1))

            # Stream results
            if view_img:
                cv2.imshow(p, im0)
                if cv2.waitKey(1) == ord('q'):  # q to quit
                    raise StopIteration

            # Save results (image with detections)
            if save_img:
                if dataset.mode == 'images':
                    cv2.imwrite(save_path, im0)
        result = {
            'image_id': image_ids,
            'score': scores,
            'class': labels_value,
            'xmin': xmin,
            'ymin': ymin,
            'xmax': xmax,
            'ymax': ymax

            }

        results.append(result)

    if save_txt or save_img:
        print('Results saved to %s' % os.getcwd() + os.sep + out)

    print('Done. (%.3fs)' % (time.time() - t0))
    return results

# %%
class opt:
    cfg='/content/yolov3-wrapper-for-custom-data/cfg/yolov3-spp-23cls.cfg'
    names='traffic.names'
    weights='weights/best_yolov3-traffic.pt'
    source='data/test'
    save_txt=True
    output='output'
    classes=False
    img_size=1024
    conf_thres=0.3
    iou_thres=0.6
    fourcc='mp4v'
    half=False
    device=''
    view_img=False
    agnostic_nms=False
    augment=False

# %%
# predict results
with torch.no_grad():
    res=detect()
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.26649e+07 parameters, 6.26649e+07 gradients
# image 1/99 data/test/Numan_(101)_jpg.rf.a9abd780ae62e7aa8a861c7693db43a3.jpg: 1024x1024 1 Pickup s, Done. (0.055s)
# image 2/99 data/test/Numan_(133)_jpg.rf.1e1ec524e09e67f50afdc03fd3ab4dca.jpg: 1024x1024 1 bicycles, 1 minivans, 1 Pickup s, Done. (0.055s)
# image 3/99 data/test/Numan_(134)_jpg.rf.0c6ae8c55579ac213d612d227bedf6d1.jpg: 1024x1024 Done. (0.055s)
# image 4/99 data/test/Numan_(150)_jpg.rf.6ddfbea281f2fb6180047674c32adf58.jpg: 1024x1024 Done. (0.055s)
# image 5/99 data/test/Numan_(154)_jpg.rf.16175a659e8d20b3f41501e182965f75.jpg: 1024x1024 1 Pickup s, Done. (0.055s)
# image 6/99 data/test/Numan_(155)_jpg.rf.4015bf8ecb5a6a6dce4ff7bdbe58398e.jpg: 1024x1024 1 Pickup s, 1 scooters, Done. (0.055s)
# image 7/99 data/test/Numan_(160)_jpg.rf.b6494c60e4bb081325a0c4090419162b.jpg: 1024x1024 Done. (0.055s)
# image 8/99 data/test/Numan_(168)_jpg.rf.1df822454fa92679c2ff869a008b2782.jpg: 1024x1024 Done. (0.055s)
# image 9/99 data/test/Numan_(181)_jpg.rf.561da12e7cd208aef2c59685c1c4c7ad.jpg: 1024x1024 1 Pickup s, Done. (0.055s)
# image 10/99 data/test/Numan_(194)_jpg.rf.269d4a4e0c4524e8e49c9f7e05f039c0.jpg: 1024x1024 3 Pickup s, 1 scooters, Done. (0.055s)
# image 11/99 data/test/Numan_(208)_jpg.rf.ff45b224c9b61369a06d6ee277d593c9.jpg: 1024x1024 Done. (0.055s)
# image 12/99 data/test/Numan_(218)_jpg.rf.3da55688ac4a517f0822153d44c6323a.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 13/99 data/test/Numan_(233)_jpg.rf.22444dc55b878a27b3cf9ce1d6b5cf06.jpg: 1024x1024 2 suvs, Done. (0.055s)
# image 14/99 data/test/Numan_(239)_jpg.rf.608b5ecaea5e6302bd423e5ed0c6137a.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 15/99 data/test/Numan_(240)_jpg.rf.f8b89e02c48d4e79ccaba7e4f2592202.jpg: 1024x1024 1 minivans, Done. (0.055s)
# image 16/99 data/test/Numan_(248)_jpg.rf.6066f9c0e94bebe05d03b368f3110db7.jpg: 1024x1024 3 bicycles, 3 minivans, Done. (0.055s)
# image 17/99 data/test/Numan_(276)_jpg.rf.ca5157ead01a1045d4d2a12a9bdc98d4.jpg: 1024x1024 2 bicycles, Done. (0.055s)
# image 18/99 data/test/Numan_(278)_jpg.rf.712ec9e2e6bcd00c1fda18a41fdaa4eb.jpg: 1024x1024 3 bicycles, Done. (0.055s)
# image 19/99 data/test/Numan_(287)_jpg.rf.b87a1868ca87fa96e7cd4eccefc3295f.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 20/99 data/test/Numan_(318)_jpg.rf.db432c503c59420b19e80a67dec3f328.jpg: 1024x1024 3 bicycles, 4 buss, 2 human haulers, 1 minibuss, 2 minivans, 2 policecars, 1 scooters, 2 suvs, 2 taxis, Done. (0.055s)
# image 21/99 data/test/Numan_(329)_jpg.rf.b7cc2d0937caa2cf84acb724417e7dce.jpg: 1024x1024 3 buss, 3 minivans, Done. (0.055s)
# image 22/99 data/test/Numan_(342)_jpg.rf.154b13b44a03ddf1e80f6df68578472c.jpg: 1024x1024 3 bicycles, 2 minivans, 1 suvs, Done. (0.055s)
# image 23/99 data/test/Numan_(351)_jpg.rf.808600fae03fabf39371d53fd8609032.jpg: 1024x1024 2 bicycles, 3 buss, 2 minivans, 1 scooters, Done. (0.055s)
# image 24/99 data/test/Numan_(357)_jpg.rf.31a038d559028442fffdc9b834d4aedc.jpg: 1024x1024 1 bicycles, 2 buss, 2 human haulers, 2 minivans, 1 taxis, Done. (0.055s)
# image 25/99 data/test/Numan_(358)_jpg.rf.8eab2f2ae8998307a74fc9588e60b5ac.jpg: 1024x1024 2 bicycles, 1 buss, 2 human haulers, 1 minivans, 1 taxis, Done. (0.055s)
# image 26/99 data/test/Numan_(364)_jpg.rf.1d7bc4464cf48e907a72809e7e5a4bfd.jpg: 1024x1024 2 auto rickshaws, 1 minibuss, 1 policecars, 1 scooters, Done. (0.055s)
# image 27/99 data/test/Numan_(368)_jpg.rf.049dc63efdc49c7fe07be9ff4b48857e.jpg: 1024x1024 1 auto rickshaws, 2 minibuss, 2 policecars, 1 scooters, 1 taxis, Done. (0.055s)
# image 28/99 data/test/Numan_(370)_jpg.rf.c096ae16165485e3dc5852f42f4bfa70.jpg: 1024x1024 3 buss, 1 minibuss, 1 Pickup s, 1 policecars, 2 scooters, Done. (0.055s)
# image 29/99 data/test/Numan_(376)_jpg.rf.990b9e85d6a63a254647187b18e8e3b3.jpg: 1024x1024 2 bicycles, Done. (0.055s)
# image 30/99 data/test/Numan_(381)_jpg.rf.7d7987a858a23aaee261a83d525422df.jpg: 1024x1024 1 auto rickshaws, 2 bicycles, 1 buss, 1 suvs, Done. (0.055s)
# image 31/99 data/test/Numan_(388)_jpg.rf.abe9c5dd62fea693c060c09e93371ef8.jpg: 1024x1024 1 buss, 1 minibuss, 3 Pickup s, Done. (0.055s)
# image 32/99 data/test/Numan_(392)_jpg.rf.c3b63364706ec7701585f8ed47b56301.jpg: 1024x1024 1 buss, 3 Pickup s, 1 scooters, Done. (0.055s)
# image 33/99 data/test/Numan_(429)_jpg.rf.294667a86d9a710ac6538380c2cb8b1c.jpg: 1024x1024 1 auto rickshaws, 3 buss, 1 minibuss, Done. (0.055s)
# image 34/99 data/test/Numan_(435)_jpg.rf.51fff3cb0ca126d3e25f8edcc3266f6c.jpg: 1024x1024 1 policecars, 4 scooters, Done. (0.055s)
# image 35/99 data/test/Numan_(442)_jpg.rf.9488cf29ec91a7b9d4368360ed9414ba.jpg: 1024x1024 1 bicycles, 5 buss, 1 scooters, Done. (0.055s)
# image 36/99 data/test/Numan_(446)_jpg.rf.05263cd94ac1d740b883c7ebdc5c564d.jpg: 1024x1024 2 buss, 4 scooters, Done. (0.055s)
# image 37/99 data/test/Numan_(450)_jpg.rf.b025161b8d9a4a0e8f86c6dcd25867d3.jpg: 1024x1024 1 auto rickshaws, 5 buss, 1 minibuss, Done. (0.055s)
# image 38/99 data/test/Numan_(451)_jpg.rf.3f0117eee0af36bca00b16c7a26c9153.jpg: 1024x1024 1 auto rickshaws, 4 buss, 2 minibuss, Done. (0.055s)
# image 39/99 data/test/Numan_(459)_jpg.rf.9caf0a3e23ce41f2fad5f3b67b7fc1ea.jpg: 1024x1024 1 bicycles, 2 buss, 2 scooters, Done. (0.055s)
# image 40/99 data/test/Numan_(468)_jpg.rf.4aca5333a83bd85bbf5061a8196e06d9.jpg: 1024x1024 1 auto rickshaws, 1 buss, 2 minibuss, Done. (0.055s)
# image 41/99 data/test/Numan_(470)_jpg.rf.7144b21379a9673c16737293c7a87bf6.jpg: 1024x1024 1 bicycles, 2 buss, 3 scooters, Done. (0.055s)
# image 42/99 data/test/Numan_(474)_jpg.rf.f49d009e5144f28467432d867490f265.jpg: 1024x1024 2 buss, 1 minibuss, 2 scooters, Done. (0.055s)
# image 43/99 data/test/Numan_(478)_jpg.rf.27ccf76c15c8ac786b7f7d747263792e.jpg: 1024x1024 1 bicycles, 1 buss, 1 minibuss, 1 policecars, 1 scooters, Done. (0.055s)
# image 44/99 data/test/Numan_(96)_jpg.rf.5e4b6d347611cd5a26b34380aae7f0df.jpg: 1024x1024 Done. (0.055s)
# image 45/99 data/test/Pias (108)_jpg.rf.bafb68c4ca3d192716b9cc5ad94eee9d.jpg: 1024x1024 6 buss, 1 minibuss, 2 minivans, 2 policecars, Done. (0.055s)
# image 46/99 data/test/Pias (117)_jpg.rf.8e15f197e63bc93fc261d4d466e10924.jpg: 1024x1024 7 buss, 1 human haulers, 1 policecars, Done. (0.055s)
# image 47/99 data/test/Pias (119)_jpg.rf.636df07d53930960b3b8830e2f640a09.jpg: 1024x1024 1 auto rickshaws, 3 buss, 2 minibuss, 1 scooters, Done. (0.055s)
# image 48/99 data/test/Pias (130)_jpg.rf.72c0ab4ebee62a999f7e75a23af23ce3.jpg: 1024x1024 4 buss, 3 human haulers, 1 minivans, 3 policecars, 2 taxis, Done. (0.055s)
# image 49/99 data/test/Pias (138)_jpg.rf.c80e95e4905006d9b3ca2d96efa17cdc.jpg: 1024x1024 1 bicycles, 5 buss, 1 taxis, Done. (0.055s)
# image 50/99 data/test/Pias (145)_jpg.rf.b9c7ff80f0ec8d1ea4151c34918e442e.jpg: 1024x1024 2 buss, 3 minibuss, 1 policecars, Done. (0.055s)
# image 51/99 data/test/Pias (15)_jpg.rf.9813a15e2c31d3219a593ff6047caad0.jpg: 1024x1024 1 bicycles, 4 buss, 3 minivans, Done. (0.055s)
# image 52/99 data/test/Pias (160)_jpg.rf.fda96397a6e2b1823f1f14c112f34b19.jpg: 1024x1024 3 buss, 1 human haulers, 1 minibuss, 1 taxis, Done. (0.055s)
# image 53/99 data/test/Pias (185)_jpg.rf.6e4f9377f213bdc7291ecbf7cdf66d9e.jpg: 1024x1024 1 bicycles, 3 buss, 3 minibuss, 1 scooters, 1 taxis, Done. (0.055s)
# image 54/99 data/test/Pias (2)_jpg.rf.8e0b8619963c0877d983609f246c7250.jpg: 1024x1024 1 auto rickshaws, 1 bicycles, 1 minibuss, Done. (0.055s)
# image 55/99 data/test/Pias (210)_jpg.rf.6114ec4be6e47ca85e6f1be21b4283c7.jpg: 1024x1024 1 bicycles, 1 buss, 1 Pickup s, 1 rickshaws, 1 scooters, Done. (0.055s)
# image 56/99 data/test/Pias (220)_jpg.rf.21f915e7dea7314cb55971c0362e21a6.jpg: 1024x1024 2 bicycles, 4 Pickup s, Done. (0.055s)
# image 57/99 data/test/Pias (238)_jpg.rf.e6e3fddc32f1ef2cce500b0767aebf3c.jpg: 1024x1024 1 bicycles, 1 human haulers, 1 minibuss, Done. (0.055s)
# image 58/99 data/test/Pias (246)_jpg.rf.0258813ccf855630e5cbe7fac1a85eb1.jpg: 1024x1024 1 bicycles, 3 buss, 1 minibuss, 3 scooters, 2 taxis, Done. (0.055s)
# image 59/99 data/test/Pias (252)_jpg.rf.7ccc47bdc6e475adb82e8894c5ff45ba.jpg: 1024x1024 2 minibuss, Done. (0.055s)
# image 60/99 data/test/Pias (261)_jpg.rf.869b7d60655e6df2e4947f216f2ca704.jpg: 1024x1024 1 bicycles, 2 buss, 1 human haulers, 1 minibuss, 1 minivans, 2 scooters, 2 taxis, Done. (0.055s)
# image 61/99 data/test/Pias (269)_jpg.rf.be7443aa289ea6bcca355a88a4127289.jpg: 1024x1024 2 buss, 4 minibuss, 1 minivans, 1 policecars, 3 scooters, 2 taxis, Done. (0.055s)
# image 62/99 data/test/Pias (283)_jpg.rf.f78e10d698fa7fec6ebf66f8615ea5e3.jpg: 1024x1024 1 bicycles, 1 scooters, Done. (0.055s)
# image 63/99 data/test/Pias (284)_jpg.rf.d243bb78ee94a3529459f0a7ae8e8871.jpg: 1024x1024 1 bicycles, 1 scooters, Done. (0.055s)
# image 64/99 data/test/Pias (287)_jpg.rf.6d317f94f8baf4f1346ac8f8ad1afb80.jpg: 1024x1024 2 buss, 2 minibuss, Done. (0.055s)
# image 65/99 data/test/Pias (303)_jpg.rf.5a69893c36761c4981faa08c4d051302.jpg: 1024x1024 2 bicycles, 2 buss, 1 minibuss, Done. (0.055s)
# image 66/99 data/test/Pias (304)_jpg.rf.3803ffcc25e91d70b6ce3c9775032cdb.jpg: 1024x1024 2 bicycles, 2 buss, 1 scooters, Done. (0.055s)
# image 67/99 data/test/Pias (311)_jpg.rf.10a4979a32f84cdf7cdd2e73aa6a4cdd.jpg: 1024x1024 3 bicycles, 1 buss, 2 scooters, Done. (0.055s)
# image 68/99 data/test/Pias (316)_jpg.rf.639cd443adc7c0a1c68ebdfb1d1fdc35.jpg: 1024x1024 1 Pickup s, 1 scooters, Done. (0.055s)
# image 69/99 data/test/Pias (317)_jpg.rf.ee86db77554e0b59473f7f25f1a1ca40.jpg: 1024x1024 1 bicycles, 2 minibuss, 1 scooters, Done. (0.055s)
# image 70/99 data/test/Pias (32)_jpg.rf.bc81944b8ddd08106aba05cf1fc3d4d7.jpg: 1024x1024 4 buss, 2 minivans, 1 taxis, Done. (0.055s)
# image 71/99 data/test/Pias (323)_jpg.rf.20af769e6b42825e3058cfdd1337b833.jpg: 1024x1024 2 buss, 1 Pickup s, Done. (0.055s)
# image 72/99 data/test/Pias (325)_jpg.rf.43c29049a58a55b08ce6e16a365332e3.jpg: 1024x1024 1 bicycles, 1 buss, Done. (0.055s)
# image 73/99 data/test/Pias (36)_jpg.rf.ed3f816bc276c875ceacd420d96c4b90.jpg: 1024x1024 7 buss, 1 human haulers, 1 minibuss, 2 scooters, Done. (0.055s)
# image 74/99 data/test/Pias (370)_jpg.rf.553d262249832fc1b3d84d01b2f68aee.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 75/99 data/test/Pias (387)_jpg.rf.fc8ac683f5d0e419795a74389ad1caec.jpg: 1024x1024 1 bicycles, 1 buss, 1 minivans, 1 suvs, Done. (0.055s)
# image 76/99 data/test/Pias (389)_jpg.rf.5c897194d165c4b232c383edaa3e56ad.jpg: 1024x1024 1 bicycles, Done. (0.055s)
# image 77/99 data/test/Pias (400)_jpg.rf.77bb7c4a014918cc7203b7e60e27eab9.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 78/99 data/test/Pias (412)_jpg.rf.80596e4d0c666398c5e54f40e200a678.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 79/99 data/test/Pias (417)_jpg.rf.2101950bc7d4945ff6af147a59bd14b1.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 80/99 data/test/Pias (431)_jpg.rf.20ceae3fead9bbcaf741404975312438.jpg: 1024x1024 1 bicycles, 1 buss, 4 suvs, Done. (0.055s)
# image 81/99 data/test/Pias (436)_jpg.rf.8d2f4d3600bbd5f39e87653faa702f0b.jpg: 1024x1024 2 bicycles, 1 buss, 1 suvs, Done. (0.055s)
# image 82/99 data/test/Pias (439)_jpg.rf.a8207c59e7767c980dd2ce4afdfa71a2.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 83/99 data/test/Pias (448)_jpg.rf.2b645955638544e0e5661123012db9f3.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 84/99 data/test/Pias (451)_jpg.rf.d2f638c1a80e3c1961e192d6de5fb1f9.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 85/99 data/test/Pias (475)_jpg.rf.cc2cd256b2f9d99e5365dc625cec5a32.jpg: 1024x1024 1 scooters, 1 suvs, Done. (0.055s)
# image 86/99 data/test/Pias (498)_jpg.rf.5ab9e7c827e784ed4153f74bab462380.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 87/99 data/test/Pias (5)_jpg.rf.521ba2088de4eb206ca42942a16dea49.jpg: 1024x1024 1 bicycles, 1 buss, 1 scooters, Done. (0.055s)
# image 88/99 data/test/Pias (500)_jpg.rf.128466983b17907c0aa1b583d74543cc.jpg: 1024x1024 1 minivans, 1 suvs, Done. (0.055s)
# image 89/99 data/test/Pias (508)_jpg.rf.f330d3973eb0bbd9acaae1fb9074b0c0.jpg: 1024x1024 Done. (0.055s)
# image 90/99 data/test/Pias (510)_jpg.rf.5343c66c4fb5552c43f34d69f7cae22f.jpg: 1024x1024 2 suvs, Done. (0.055s)
# image 91/99 data/test/Pias (515)_jpg.rf.6739c04be13a632265191763fd390c07.jpg: 1024x1024 2 suvs, Done. (0.055s)
# image 92/99 data/test/Pias (522)_jpg.rf.b33d3063333d055d649e0c0caeae25ee.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 93/99 data/test/Pias (528)_jpg.rf.17d95444f4e2d18711ebc089b1c07095.jpg: 1024x1024 1 auto rickshaws, 1 minibuss, 1 minivans, 2 suvs, Done. (0.055s)
# image 94/99 data/test/Pias (53)_jpg.rf.52a69f8fab24261280c9307cfa8228a4.jpg: 1024x1024 2 buss, 2 human haulers, 1 minibuss, 2 policecars, 1 scooters, Done. (0.055s)
# image 95/99 data/test/Pias (530)_jpg.rf.9006dc8bf88ca6a9f8cfb65637b1a449.jpg: 1024x1024 1 suvs, Done. (0.055s)
# image 96/99 data/test/Pias (541)_jpg.rf.d39e25a1333af40f0596c2c6f2cff192.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 97/99 data/test/Pias (544)_jpg.rf.34731a6fbdb62f2f3f3c706e1ddde155.jpg: 1024x1024 1 bicycles, 1 suvs, Done. (0.055s)
# image 98/99 data/test/Pias (61)_jpg.rf.dc6d4e4ca249d84d2c7459f7a54eeadd.jpg: 1024x1024 1 buss, 1 policecars, 1 scooters, 1 taxis, Done. (0.055s)
# image 99/99 data/test/Pias (62)_jpg.rf.c80d5b8ab2f31e47542e3ddf917d83fc.jpg: 1024x1024 2 buss, 1 human haulers, 1 minibuss, 1 minivans, 3 policecars, Done. (0.055s)
# Results saved to /content/yolov3-wrapper-for-custom-data/output
# Done. (9.094s)

# %% [markdown]
# ### Submission file structure
#
# In the submission file you need to have to following headers with values
#
#
#
# *   image_id
# *   class
# *   score
# *   xmin
# *   ymin
# *   xmax
# *   ymax
# *   height
# *   width
#
# **Remember all the test images are rescaled into 1024x1024 so the bounding boxes must be scaled for 1024x1024 image size**

# %%
import pandas as pd
import numpy as np

append_data=[]

for i in range(len(res)):
  
  df = pd.DataFrame(res[i], columns = ['image_id','class','score','xmin','ymin','xmax','ymax'])
 
  append_data.append(df)

finl_results=pd.concat(append_data)

finl_results.image_id = [x.strip('output/') for x in finl_results.image_id]

finl_results['width'] = 1024
finl_results['height'] = 1024
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-813058277074> in <module>()
#       4 append_data=[]
#       5
# ----> 6 for i in range(len(res)):
#       7
#       8   df = pd.DataFrame(res[i], columns = ['image_id','class','score','xmin','ymin','xmax','ymax'])
#
# NameError: name 'res' is not defined

# %%
finl_results.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d4b70aa810c2> in <module>()
# ----> 1 finl_results.head()
#
# NameError: name 'finl_results' is not defined

# %%
finl_results.to_csv('submission.csv', index=False)
